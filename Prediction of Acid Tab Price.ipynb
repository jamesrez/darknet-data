# %% [markdown]
# ## Is it possible to predict a semi-accurate price for a tab of lsd, based on its dose measurement, rating, and origin?

# %%
darknet_data_path = './datasets/agora_fixed.csv'
#Import everything needed for the project.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Clean it up for only LSD items
darkDf = pd.read_csv(darknet_data_path)
darkDf
drugsDf = darkDf[darkDf[" Category"].str.contains("Drugs")]
acidDf = drugsDf[drugsDf[" Category"].str.contains("LSD")]
acidDf = acidDf[acidDf[" Item"].str.contains("LSD|lsd|Lsd|Acid|acid|ACID|ug|UG|mcg")]
acidDf = acidDf[~acidDf[" Item"].str.contains("LAD|Bottle")]
acidDf
# Out:
#                       Vendor                Category  \
# 14426                FelixUK  Drugs/Psychedelics/LSD
# 14427            MEGA_PHARMA  Drugs/Psychedelics/LSD
# 14428            MEGA_PHARMA  Drugs/Psychedelics/LSD
# 14429                  Dekay  Drugs/Psychedelics/LSD
# 14430            value.lucid  Drugs/Psychedelics/LSD
# 14431            value.lucid  Drugs/Psychedelics/LSD
# 14433             MrSunshine  Drugs/Psychedelics/LSD
# 14434        HigherGroundsNL  Drugs/Psychedelics/LSD
# 14435            value.lucid  Drugs/Psychedelics/LSD
# 14436              SpiceGirl  Drugs/Psychedelics/LSD
# 14437              SpiceGirl  Drugs/Psychedelics/LSD
# 14439              Tr4derJo3  Drugs/Psychedelics/LSD
# 14440                FelixUK  Drugs/Psychedelics/LSD
# 14441                 p3nd8s  Drugs/Psychedelics/LSD
# 14442            value.lucid  Drugs/Psychedelics/LSD
# 14443               topdeals  Drugs/Psychedelics/LSD
# 14444            value.lucid  Drugs/Psychedelics/LSD
# 14445            value.lucid  Drugs/Psychedelics/LSD
# 14446              Tr4derJo3  Drugs/Psychedelics/LSD
# 14447                 MERLIN  Drugs/Psychedelics/LSD
# 14448                    P3z  Drugs/Psychedelics/LSD
# 14449            value.lucid  Drugs/Psychedelics/LSD
# 14450              Tr4derJo3  Drugs/Psychedelics/LSD
# 14451               -Inanna-  Drugs/Psychedelics/LSD
# 14452             FreshTouch  Drugs/Psychedelics/LSD
# 14453              SpiceGirl  Drugs/Psychedelics/LSD
# 14454                 MERLIN  Drugs/Psychedelics/LSD
# 14455             BlueViking  Drugs/Psychedelics/LSD
# 14457              jerseycow  Drugs/Psychedelics/LSD
# 14458            value.lucid  Drugs/Psychedelics/LSD
# ...                      ...                     ...
# 62990                starbuy  Drugs/Psychedelics/LSD
# 62991               Peaceful  Drugs/Psychedelics/LSD
# 62992              Hollandia  Drugs/Psychedelics/LSD
# 62993                Psymama  Drugs/Psychedelics/LSD
# 62994               Peaceful  Drugs/Psychedelics/LSD
# 62995               PsyStorm  Drugs/Psychedelics/LSD
# 62996  TheGratefulDeadFamily  Drugs/Psychedelics/LSD
# 62997                gogogoz  Drugs/Psychedelics/LSD
# 62998               Peaceful  Drugs/Psychedelics/LSD
# 62999              InTransit  Drugs/Psychedelics/LSD
# 63000               SoupNazi  Drugs/Psychedelics/LSD
# 63001               Peaceful  Drugs/Psychedelics/LSD
# 63004              Markovich  Drugs/Psychedelics/LSD
# 63005               KarmaLab  Drugs/Psychedelics/LSD
# 63008                 SCIdmt  Drugs/Psychedelics/LSD
# 63009              InTransit  Drugs/Psychedelics/LSD
# 63010           KittenHuffer  Drugs/Psychedelics/LSD
# 63011            NelsonMuntz  Drugs/Psychedelics/LSD
# 63012            PsychNorway  Drugs/Psychedelics/LSD
# 63013          DutchDelights  Drugs/Psychedelics/LSD
# 63014       HumanTraffic-Jip  Drugs/Psychedelics/LSD
# 63015       HumanTraffic-Jip  Drugs/Psychedelics/LSD
# 63016             Instrument  Drugs/Psychedelics/LSD
# 63017          DutchDelights  Drugs/Psychedelics/LSD
# 63018         ThePinkPanther  Drugs/Psychedelics/LSD
# 63019       HumanTraffic-Jip  Drugs/Psychedelics/LSD
# 63020            NelsonMuntz  Drugs/Psychedelics/LSD
# 63021        Dr.FeelGoodMeds  Drugs/Psychedelics/LSD
# 63022       HumanTraffic-Jip  Drugs/Psychedelics/LSD
# 63023            NelsonMuntz  Drugs/Psychedelics/LSD
#
#                                                     Item  \
# 14426  FelixUK (10) - 110ug Hofmann Blotter Dutch LSD...
# 14427              LSD acid blotter (130+ ug) 2 blotters
# 14428               LSD acid blotter (130+ ug) 1 blotter
# 14429                                     2 LSD Blotters
# 14430  25 x Alex Grey's Hofmann LSD Acid (25 x 100 - ...
# 14431  1 x Alex Grey's Hofmann LSD Acid (1 x 100 - 12...
# 14433  FREE DRUGS buy 2 hits of LSD get 1 of Mescalin...
# 14434                   10 pcs High Quality LSD Blotters
# 14435  15 x Alex Grey's Hofmann LSD Acid (15 x 100 - ...
# 14436                                  100 tab 120ug LSD
# 14437                                    5 tab 120ug LSD
# 14439        10 x Dutch LSD Dalai Lama 225ug LAB TESTED!
# 14440  FelixUK (100) - 110ug Hofmann Blotter Dutch LS...
# 14441  Claviceps Paspali Culture on PDA Make 1.5g/L L...
# 14442  5 x 225ug LSDJubilee Bunny Hofmanns Needlepoin...
# 14443                                Red Microdot LSD x1
# 14444  100 x 225ug LSDJubilee Bunny Hofmanns Needlepo...
# 14445  10 x Alex Grey's Hofmann LSD Acid (10 x 100 - ...
# 14446        25 x Dutch LSD Dalai Lama 225ug LAB TESTED!
# 14447        x100 Drops LSD Liquid Vial (130ug per drop)
# 14448                   50 x LSD-25 - Yoda print blotter
# 14449  200 x Alex Grey's Hofmann LSD Acid (200 x 100 ...
# 14450         5 x Dutch LSD Dalai Lama 225ug LAB TESTED!
# 14451            50 X Brown Microdots Swiss Fluff 125 ug
# 14452                        5x Albert Hoffmann LSD tabs
# 14453                                   50 tab 120ug LSD
# 14454                      50x MERLIN's SUNFLOWERS 120ug
# 14455                      5x 240ug Liquid Dosed Gummies
# 14457              LSD - YODA - 50x BLOTTERS 140ug SWISS
# 14458  100 x Alex Grey's Hofmann LSD Acid (100 x 100 ...
# ...                                                  ...
# 62990                Starbuys Super Cherry's 115ug x 200
# 62991  [ESCROW] 30 x 150ug Imported LSD Blotters - PU...
# 62992                         50x Blotter | 140Âµg | LSD
# 62993  50x150ug Premium Australian LSD blotters.( Promo)
# 62994  [ESCROW] 600 x 150ug Imported LSD Blotters - P...
# 62995  1x WoW LSD 200ug - One hit of White on White Acid
# 62996                       20 X 100 UG LSD-25 ESCROW :D
# 62997                    5X 110 mcg House White LSD tabs
# 62998  [ESCROW] 250 x 150ug Imported LSD Blotters - P...
# 62999                     1 x â™¥LSD (200ug) IMPORTEDâ™¥
# 63000                             107.6ug 97%+ LSD (100)
# 63001  [ESCROW] 200 x 150ug Imported LSD Blotters - P...
# 63004                               5x 160ug Hanuman LSD
# 63005   50x Liquid LSD Drops 200Âµg LSD-25 No FE Listing
# 63008                           LSD 125-150 ug 100 doses
# 63009                     5 x â™¥LSD (200ug) IMPORTEDâ™¥
# 63010                              5x 160 ug Hanuman LSD
# 63011                Nelson's LSD Blotters - 290ug - x25
# 63012                            LSD 140Âµg x 5 blotters
# 63013  250x Anonymouse HQ LSD blotters (180Î¼g) - fre...
# 63014  3x LSD Rolling Stones ~135Âµg ACID Blotter Psy...
# 63015  5x LSD Rolling Stones ~135Âµg ACID Blotter Psy...
# 63016  50x 420ug Dutch Rose Crystal Blotters <Heroic ...
# 63017  INTRO OFFER: 50x Anonymouse HQ LSD blotters (1...
# 63018  10 x Highly potent and Clean LSD Smileys 115ug...
# 63019  2 xLSD Anonymous ~150Âµg acid blotter psychede...
# 63020                Nelson's LSD Blotters - 120ug - x10
# 63021                      50 hits White fluff LSD 200ug
# 63022  2x LSD Rolling Stones ~135Âµg ACID Blotter Psy...
# 63023                 Nelson's LSD Blotters - 120ug - x5
#
#                                         Item Description  \
# 14426  10 - 110ug Hofmann Blotters Dutch LSD  We ship...
# 14427  -----------------------LSD BLOTTERS-----------...
# 14428  -----------------------LSD BLOTTERS-----------...
# 14429  PLEASE NOTE - ALL ORDERS MUST FE / FINALIZE EA...
# 14430  I offer you 25 Pieces of Alex Grey's Albert Ho...
# 14431  I offer you 1 single Piece of Alex Grey's Albe...
# 14433  2 hits of Fresh Laid "POTENT" Needlepoint 115-...
# 14434  Here we got some nice LSD blotters from Hollan...
# 14435  I offer you 15 Pieces of Alex Grey's Albert Ho...
# 14436  Yummy clean LSD. Blotter art differs from pict...
# 14437  Yummy clean LSD. Blotter art differs from pict...
# 14439  10 x Dutch LSD Dalai Lama 225ug LAB TESTED!  R...
# 14440  100 - 110ug Hofmann Blotters Dutch LSD  We shi...
# 14441  CLAVICEPS PASPALI CULTURE - High yielding Stev...
# 14442  I offer you 5 Pieces of Jubilee Bunny Hofmanns...
# 14443                                Red Microdot LSD x1
# 14444  I offer you 100 Pieces of Jubilee Bunny Hofman...
# 14445  I offer you 10 Pieces of Alex Grey's Albert Ho...
# 14446  25 x Dutch LSD Dalai Lama 225ug LAB TESTED!  R...
# 14447  Broceliand Family Liquid LSD  Me and my belove...
# 14448  This is a listing for 25 Yoda print LSD blotte...
# 14449  I offer you 200 Pieces of Alex Grey's Albert H...
# 14450  5 x Dutch LSD Dalai Lama 225ug LAB TESTED!  Re...
# 14451  50 X Brown Microdots 125 ug Crystal : Swiss Fl...
# 14452  5x Albert Hofmann bicycle LSD tabs.  Very nice...
# 14453  Yummy clean LSD. Blotter art differs from pict...
# 14454  Broceliand Family  Me and my beloved trees in ...
# 14455  *ALL LISTINGS NOW REQUIRE FE. DUE TO ALL OF TH...
# 14457  Yoda print LSD - FRESH & NEW - December 2013 L...
# 14458  I offer you 100 Pieces of Alex Grey's Albert H...
# ...                                                  ...
# 62990                Starbuys Super Cherry's 115ug x 200
# 62991  â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â...
# 62992  Premium quality LSD  made in Holland. We're 10...
# 62993  Dear Psychedelic customers  These are the same...
# 62994  â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â...
# 62995  One hit of White on White LSD. 200ug doses.  S...
# 62996  Friends  Patrons  The Grateful Dead Family is ...
# 62997  Please check my vendor page for quality servic...
# 62998  â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â...
# 62999  1 x LSD TABS (200ug)   These tabs are strong  ...
# 63000  If you sampled my liquid and liked it  then yo...
# 63001  â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â™¥â...
# 63004  Beautiful tabs with a beautiful print. These H...
# 63005  You receive 50x Liquid LSD Drops solved in 70%...
# 63008  This is very clean and potent WOW LSD.  You'll...
# 63009  5 x LSD TABS (200ug)   These tabs are strong  ...
# 63010  The LSD laid on these tabs is of the same puri...
# 63011  *** PLEASE READ ALL INFO ON PRODUCT PAGE AND V...
# 63012  This listing is for Ganesha LSD 140 blotters s...
# 63013  With pride we introduce our unique press of th...
# 63014  LSD Rolling Stones ~135Âµg ACID Blotter Psyche...
# 63015  LSD Rolling Stones ~135Âµg ACID Blotter Psyche...
# 63016  Dream all of your future... relive all of your...
# 63017  With pride we introduce our unique press of th...
# 63018  (PROMOTION LISTING)Original LSD. No substituti...
# 63019  LSD Anonymous ~150Âµg acid blotter psychedelic...
# 63020  *** PLEASE READ ALL INFO ON PRODUCT PAGE AND V...
# 63021  This listing is for 50 hits of LSD 200ug.  Wor...
# 63022  LSD Rolling Stones ~135Âµg ACID Blotter Psyche...
# 63023  *** PLEASE READ ALL INFO ON PRODUCT PAGE AND V...
#
#                           Price       Origin  \
# 14426   0.14345433142857145 BTC           UK
# 14427            0.04109156 BTC        World
# 14428  0.021238328181818183 BTC        World
# 14429            0.06896385 BTC    Australia
# 14430    0.4764299111111112 BTC      Germany
# 14431   0.02418582220588236 BTC      Germany
# 14433   0.04278990590909092 BTC          USA
# 14434            0.13974562 BTC  Netherlands
# 14435   0.28554621927835044 BTC      Germany
# 14436     1.778981541764706 BTC    Australia
# 14437    0.1497232238461538 BTC    Australia
# 14439   0.27969047500000005 BTC      Germany
# 14440    1.0231667150000001 BTC           UK
# 14441     4.740260556666666 BTC          USA
# 14442   0.13396833666666663 BTC      Germany
# 14443  0.027060530714285713 BTC          NaN
# 14444     2.023297351333333 BTC      Germany
# 14445   0.18924345839080461 BTC      Germany
# 14446    0.7128599865957449 BTC      Germany
# 14447           1.120129924 BTC       France
# 14448    0.6458970543333334 BTC           EU
# 14449     3.448890391037735 BTC      Germany
# 14450   0.15320380166666667 BTC      Germany
# 14451    0.9922907608333329 BTC          USA
# 14452   0.09274594666666665 BTC           EU
# 14453    1.1558194155555557 BTC    Australia
# 14454            0.58211476 BTC       France
# 14455   0.10323747666666666 BTC          USA
# 14457    0.5256043955555555 BTC       France
# 14458    1.8044311242708335 BTC      Germany
# ...                         ...          ...
# 62990           4.063492745 BTC           UK
# 62991    1.2438068245714287 BTC    Australia
# 62992    0.9015363566666666 BTC  Netherlands
# 62993    1.4678047566666663 BTC    Australia
# 62994    15.128581522500005 BTC    Australia
# 62995   0.04668307124999999 BTC          USA
# 62996    0.5749981833333333 BTC          USA
# 62997            0.18298386 BTC    Australia
# 62998     6.990310780000001 BTC    Australia
# 62999   0.07046171333333333 BTC    Australia
# 63000            2.16877333 BTC          USA
# 63001     5.730078764722224 BTC    Australia
# 63004   0.16292941588235288 BTC  Netherlands
# 63005    0.9799961753846153 BTC      Germany
# 63008    2.0839164949999995 BTC          USA
# 63009   0.24463448733333332 BTC    Australia
# 63010   0.16763280719999998 BTC  Netherlands
# 63011    1.1028146499999998 BTC           UK
# 63012   0.40593139347826085 BTC       Norway
# 63013     4.886553391749998 BTC  Netherlands
# 63014   0.07647601740740739 BTC      Germany
# 63015    0.1255619096153846 BTC      Germany
# 63016     4.060672539354838 BTC          USA
# 63017    0.8961681226470586 BTC  Netherlands
# 63018   0.10933461571428572 BTC  Netherlands
# 63019   0.05502957785714285 BTC      Germany
# 63020    0.2288866110526316 BTC           UK
# 63021    1.3068215105882353 BTC          USA
# 63022   0.05193791115384615 BTC      Germany
# 63023   0.13009140210526313 BTC           UK
#
#                                 Destination     Rating  \
# 14426                             Worldwide       ~5/5
# 14427                             Worldwide      4.7/5
# 14428                             Worldwide      4.7/5
# 14429                             Australia       ~5/5
# 14430  Everywhere Worldwide any Destination      5.0/5
# 14431  Everywhere Worldwide any Destination      5.0/5
# 14433                                   NaN      4.7/5
# 14434                                   NaN       ~5/5
# 14435  Everywhere Worldwide any Destination      5.0/5
# 14436                             Australia       ~5/5
# 14437                                   NaN       ~5/5
# 14439                                    EU      4.8/5
# 14440                             Worldwide       ~5/5
# 14441                                   NaN  [0 deals]
# 14442  Everywhere Worldwide any Destination      5.0/5
# 14443                                   NaN       ~5/5
# 14444  Everywhere Worldwide any Destination      5.0/5
# 14445  Everywhere Worldwide any Destination      5.0/5
# 14446                                    EU      4.8/5
# 14447                                 WORLD  [0 deals]
# 14448                                   NaN       ~5/5
# 14449  Everywhere Worldwide any Destination      5.0/5
# 14450                                    EU      4.8/5
# 14451                                   NaN  [0 deals]
# 14452                      World Except USA  [0 deals]
# 14453                                   NaN       ~5/5
# 14454                                 WORLD  [0 deals]
# 14455                             Worldwide      5.0/5
# 14457                                   NaN      5.0/5
# 14458  Everywhere Worldwide any Destination      5.0/5
# ...                                     ...        ...
# 62990                                 world     4.62/5
# 62991                                   NaN    5.000/5
# 62992                             Worldwide     4.97/5
# 62993                             Worldwide     5.00/5
# 62994                                   NaN    5.000/5
# 62995                        USA and Canada     4.97/5
# 62996                                   NaN     4.97/5
# 62997                             Australia     5.00/5
# 62998                                   NaN    5.000/5
# 62999                             Australia     4.95/5
# 63000                                   NaN     5.00/5
# 63001                                   NaN    5.000/5
# 63004                  Please check listing    4.968/5
# 63005                                   NaN     4.95/5
# 63008                             worldwide     4.95/5
# 63009                             Australia     4.95/5
# 63010                                   NaN    4.994/5
# 63011                             Worldwide       ~5/5
# 63012                                   NaN       ~5/5
# 63013   WorldWide (except USA/AUS/DOMESTIC)     4.55/5
# 63014                                europe     4.87/5
# 63015                                europe     4.87/5
# 63016                                   NaN    4.995/5
# 63017   WorldWide (except USA/AUS/DOMESTIC)     4.55/5
# 63018                  Worldwide except USA     4.67/5
# 63019                                europe     4.87/5
# 63020                             Worldwide       ~5/5
# 63021                                   USA  3~5 deals
# 63022                             worldwide     4.87/5
# 63023                             Worldwide       ~5/5
#
#                                                  Remarks
# 14426                                                NaN
# 14427                                                NaN
# 14428                                                NaN
# 14429                                                NaN
# 14430                                                NaN
# 14431                                                NaN
# 14433                                                NaN
# 14434                                                NaN
# 14435                                                NaN
# 14436  Average price may be skewed outliar > .5 BTC f...
# 14437                                                NaN
# 14439                                                NaN
# 14440                                                NaN
# 14441  Average price may be skewed outliar > .5 BTC f...
# 14442                                                NaN
# 14443                                                NaN
# 14444                                                NaN
# 14445                                                NaN
# 14446                                                NaN
# 14447                                                NaN
# 14448                                                NaN
# 14449  Average price may be skewed outliar > .5 BTC f...
# 14450                                                NaN
# 14451  Average price may be skewed outliar > .5 BTC f...
# 14452                                                NaN
# 14453                                                NaN
# 14454                                                NaN
# 14455                                                NaN
# 14457                                                NaN
# 14458  Average price may be skewed outliar > .5 BTC f...
# ...                                                  ...
# 62990                                                NaN
# 62991                                                NaN
# 62992                                                NaN
# 62993                                                NaN
# 62994  Average price may be skewed outliar > .5 BTC f...
# 62995                                                NaN
# 62996                                                NaN
# 62997                                                NaN
# 62998  Average price may be skewed outliar > .5 BTC f...
# 62999                                                NaN
# 63000                                                NaN
# 63001  Average price may be skewed outliar > .5 BTC f...
# 63004                                                NaN
# 63005                                                NaN
# 63008                                                NaN
# 63009                                                NaN
# 63010                                                NaN
# 63011                                                NaN
# 63012                                                NaN
# 63013  Average price may be skewed outliar > .5 BTC f...
# 63014                                                NaN
# 63015                                                NaN
# 63016                                                NaN
# 63017                                                NaN
# 63018                                                NaN
# 63019                                                NaN
# 63020                                                NaN
# 63021  Average price may be skewed outliar > .5 BTC f...
# 63022                                                NaN
# 63023                                                NaN
#
# [1952 rows x 9 columns]

# %%
# Get rid of unnecessary Columns
acidDf = acidDf.drop(["Vendor", " Category", " Item Description", " Destination", " Remarks"], axis=1)


# Extract Dose From Item Name
import re
def getDose(row):
    itemName = row[" Item"]
    regex = "\d*(?=(ug|Âµg|mcg))"
    dosage = re.search(regex, itemName)
    if dosage and dosage.group().isdigit():
        return dosage.group()

def getQuantity(row):
    itemName = row[" Item"]
    regex = "\d*(?=(x|X| x|  x| X| tab| Tab| hits| hit| pcs| doses| blotters| blotter| Blots| stamps))"
    dosage = re.search(regex, itemName)
    if dosage and dosage.group().isdigit() and not dosage.group() == "000":
        return dosage.group()
    else:
        regex = "\d*(?!(x|x |X|X ))"
        dosage = re.search(regex, itemName)
        if dosage and dosage.group().isdigit():
            return dosage.group()


acidDf["Dose"] = acidDf.apply(lambda row: getDose(row), axis=1)
acidDf["Quantity"] = acidDf.apply(lambda row: getQuantity(row), axis=1)

acidDf.dropna(subset=['Quantity'], inplace=True)
acidDf.dropna(subset=['Dose'], inplace=True)
acidDf
# Out:
#                                                     Item  \
# 14430  25 x Alex Grey's Hofmann LSD Acid (25 x 100 - ...
# 14431  1 x Alex Grey's Hofmann LSD Acid (1 x 100 - 12...
# 14435  15 x Alex Grey's Hofmann LSD Acid (15 x 100 - ...
# 14436                                  100 tab 120ug LSD
# 14437                                    5 tab 120ug LSD
# 14439        10 x Dutch LSD Dalai Lama 225ug LAB TESTED!
# 14442  5 x 225ug LSDJubilee Bunny Hofmanns Needlepoin...
# 14444  100 x 225ug LSDJubilee Bunny Hofmanns Needlepo...
# 14445  10 x Alex Grey's Hofmann LSD Acid (10 x 100 - ...
# 14446        25 x Dutch LSD Dalai Lama 225ug LAB TESTED!
# 14447        x100 Drops LSD Liquid Vial (130ug per drop)
# 14449  200 x Alex Grey's Hofmann LSD Acid (200 x 100 ...
# 14450         5 x Dutch LSD Dalai Lama 225ug LAB TESTED!
# 14453                                   50 tab 120ug LSD
# 14454                      50x MERLIN's SUNFLOWERS 120ug
# 14455                      5x 240ug Liquid Dosed Gummies
# 14457              LSD - YODA - 50x BLOTTERS 140ug SWISS
# 14458  100 x Alex Grey's Hofmann LSD Acid (100 x 100 ...
# 14459           50x LSD Blotters 125ug Czech Silver Xtal
# 14460                            5x 225ug Dalai Lama LSD
# 14461            LSD - SHIVA - 500x BLOTTERS 140ug SWISS
# 14462            25x LSD Blotters 185ug Mayan White Xtal
# 14463        Beatles (Dutch Silver-Grey) 110ug - 50 hits
# 14465                            1x 225ug Dalai Lama LSD
# 14467                           50x 225ug Dalai Lama LSD
# 14468            10x LSD Blotters 185ug Mayan White Xtal
# 14472  10 x 225ug LSDJubilee Bunny Hofmanns Needlepoi...
# 14476  10 x TragicallyHip's Dutch Shiva LSD Blotters ...
# 14477                           10x 225ug Dalai Lama LSD
# 14480                              25 Fat Freddy's 180ug
# ...                                                  ...
# 62973                               3x 160ug Hanuman LSD
# 62975  NEW PRODUCT OFFER 50x HQ DUTCH LSD BLOTTERS 18...
# 62977      50x Bears Blotter 200Âµg LSD-25 No FE Listing
# 62978  **Promo**-10x150ug Premium Australian LSD blot...
# 62981                              107.6ug 97%+ LSD (10)
# 62982  100x Liquid LSD Drops 200Âµg LSD-25 No FE Listing
# 62983  [ESCROW] 10 x 150ug Imported LSD Blotters - PU...
# 62985  [ESCROW] 50 x 150ug Imported LSD Blotters - PU...
# 62986          25x Liquid LSD Drops 200Âµg No FE Listing
# 62987                    50 x â™¥LSD (200ug) IMPORTEDâ™¥
# 62989                         10x Blotter | 140Âµg | LSD
# 62991  [ESCROW] 30 x 150ug Imported LSD Blotters - PU...
# 62992                         50x Blotter | 140Âµg | LSD
# 62993  50x150ug Premium Australian LSD blotters.( Promo)
# 62994  [ESCROW] 600 x 150ug Imported LSD Blotters - P...
# 62995  1x WoW LSD 200ug - One hit of White on White Acid
# 62998  [ESCROW] 250 x 150ug Imported LSD Blotters - P...
# 62999                     1 x â™¥LSD (200ug) IMPORTEDâ™¥
# 63000                             107.6ug 97%+ LSD (100)
# 63001  [ESCROW] 200 x 150ug Imported LSD Blotters - P...
# 63004                               5x 160ug Hanuman LSD
# 63005   50x Liquid LSD Drops 200Âµg LSD-25 No FE Listing
# 63009                     5 x â™¥LSD (200ug) IMPORTEDâ™¥
# 63014  3x LSD Rolling Stones ~135Âµg ACID Blotter Psy...
# 63015  5x LSD Rolling Stones ~135Âµg ACID Blotter Psy...
# 63016  50x 420ug Dutch Rose Crystal Blotters <Heroic ...
# 63018  10 x Highly potent and Clean LSD Smileys 115ug...
# 63019  2 xLSD Anonymous ~150Âµg acid blotter psychede...
# 63021                      50 hits White fluff LSD 200ug
# 63022  2x LSD Rolling Stones ~135Âµg ACID Blotter Psy...
#
#                           Price       Origin     Rating Dose Quantity
# 14430    0.4764299111111112 BTC      Germany      5.0/5  125       25
# 14431   0.02418582220588236 BTC      Germany      5.0/5  125        1
# 14435   0.28554621927835044 BTC      Germany      5.0/5  125       15
# 14436     1.778981541764706 BTC    Australia       ~5/5  120      100
# 14437    0.1497232238461538 BTC    Australia       ~5/5  120        5
# 14439   0.27969047500000005 BTC      Germany      4.8/5  225       10
# 14442   0.13396833666666663 BTC      Germany      5.0/5  225        5
# 14444     2.023297351333333 BTC      Germany      5.0/5  225      100
# 14445   0.18924345839080461 BTC      Germany      5.0/5  125       10
# 14446    0.7128599865957449 BTC      Germany      4.8/5  225       25
# 14447           1.120129924 BTC       France  [0 deals]  130      100
# 14449     3.448890391037735 BTC      Germany      5.0/5  125      200
# 14450   0.15320380166666667 BTC      Germany      4.8/5  225        5
# 14453    1.1558194155555557 BTC    Australia       ~5/5  120       50
# 14454            0.58211476 BTC       France  [0 deals]  120       50
# 14455   0.10323747666666666 BTC          USA      5.0/5  240        5
# 14457    0.5256043955555555 BTC       France      5.0/5  140       50
# 14458    1.8044311242708335 BTC      Germany      5.0/5  125      100
# 14459    0.5567710266666667 BTC          USA      5.0/5  125       50
# 14460    0.2099270354237288 BTC  Netherlands      5.0/5  225        5
# 14461           4.129142452 BTC       France      5.0/5  140      500
# 14462    0.4473624066666666 BTC          USA      5.0/5  185       25
# 14463    0.4820611966666668 BTC          USA      5.0/5  110       50
# 14465  0.052132473749999984 BTC  Netherlands      5.0/5  225        1
# 14467    1.7377013243750004 BTC  Netherlands      5.0/5  225       50
# 14468   0.18939240000000002 BTC          USA      5.0/5  185       10
# 14472   0.22478516852941174 BTC      Germany      5.0/5  225       10
# 14476            0.13173912 BTC       Canada      5.0/5  130       10
# 14477   0.41537703382978713 BTC  Netherlands      5.0/5  225       10
# 14480    0.5222408585714285 BTC  Netherlands      5.0/5  180       25
# ...                         ...          ...        ...  ...      ...
# 62973   0.10341918687500001 BTC  Netherlands    4.968/5  160        3
# 62975    0.8002949560000001 BTC  Netherlands     4.87/5  180       50
# 62977    0.9799961753846153 BTC      Germany     4.95/5  200       50
# 62978    0.2913833509090909 BTC    Australia     5.00/5  150       10
# 62981   0.34700372999999995 BTC          USA     5.00/5    6      107
# 62982    1.7966172946153849 BTC      Germany     4.95/5  200      100
# 62983   0.46348506472222223 BTC    Australia    5.000/5  150       10
# 62985    1.6862070125714284 BTC    Australia    5.000/5  150       50
# 62986    0.4425641627272727 BTC      Germany     4.95/5  200       25
# 62987    1.8405230520000002 BTC    Australia     4.95/5  200       50
# 62989   0.20079672999999998 BTC  Netherlands     4.97/5  140       10
# 62991    1.2438068245714287 BTC    Australia    5.000/5  150       30
# 62992    0.9015363566666666 BTC  Netherlands     4.97/5  140       50
# 62993    1.4678047566666663 BTC    Australia     5.00/5  150       50
# 62994    15.128581522500005 BTC    Australia    5.000/5  150      600
# 62995   0.04668307124999999 BTC          USA     4.97/5  200        1
# 62998     6.990310780000001 BTC    Australia    5.000/5  150      250
# 62999   0.07046171333333333 BTC    Australia     4.95/5  200        1
# 63000            2.16877333 BTC          USA     5.00/5    6      107
# 63001     5.730078764722224 BTC    Australia    5.000/5  150      200
# 63004   0.16292941588235288 BTC  Netherlands    4.968/5  160        5
# 63005    0.9799961753846153 BTC      Germany     4.95/5  200       50
# 63009   0.24463448733333332 BTC    Australia     4.95/5  200        5
# 63014   0.07647601740740739 BTC      Germany     4.87/5  135        3
# 63015    0.1255619096153846 BTC      Germany     4.87/5  135        5
# 63016     4.060672539354838 BTC          USA    4.995/5  420       50
# 63018   0.10933461571428572 BTC  Netherlands     4.67/5  115       10
# 63019   0.05502957785714285 BTC      Germany     4.87/5  150        2
# 63021    1.3068215105882353 BTC          USA  3~5 deals  200       50
# 63022   0.05193791115384615 BTC      Germany     4.87/5  135        2
#
# [1168 rows x 6 columns]

# %%
#convert BTC to USD and Bring Quantity to just 1 tab
avgBtcPrice = 300

def convertPrice(row):
    regex = "\*(?=( BTC))"
    btcPrice = row[" Price"][0:row[" Price"].index("B")]
    if float(row["Quantity"]) == 0:
        print(row)
    return ((float(btcPrice) * avgBtcPrice) / float(row["Quantity"]))

acidDf[" Price"] = acidDf.apply(lambda row: convertPrice(row), axis=1)
acidDf["Quantity"] = 1

# %%
# Without Taking Dosage into Consideration
# A 100ug tab costs less than a 300ug tab
acidDf
# Out:
#                                                     Item      Price  \
# 14430  25 x Alex Grey's Hofmann LSD Acid (25 x 100 - ...   5.717159
# 14431  1 x Alex Grey's Hofmann LSD Acid (1 x 100 - 12...   7.255747
# 14435  15 x Alex Grey's Hofmann LSD Acid (15 x 100 - ...   5.710924
# 14436                                  100 tab 120ug LSD   5.336945
# 14437                                    5 tab 120ug LSD   8.983393
# 14439        10 x Dutch LSD Dalai Lama 225ug LAB TESTED!   8.390714
# 14442  5 x 225ug LSDJubilee Bunny Hofmanns Needlepoin...   8.038100
# 14444  100 x 225ug LSDJubilee Bunny Hofmanns Needlepo...   6.069892
# 14445  10 x Alex Grey's Hofmann LSD Acid (10 x 100 - ...   5.677304
# 14446        25 x Dutch LSD Dalai Lama 225ug LAB TESTED!   8.554320
# 14447        x100 Drops LSD Liquid Vial (130ug per drop)   3.360390
# 14449  200 x Alex Grey's Hofmann LSD Acid (200 x 100 ...   5.173336
# 14450         5 x Dutch LSD Dalai Lama 225ug LAB TESTED!   9.192228
# 14453                                   50 tab 120ug LSD   6.934916
# 14454                      50x MERLIN's SUNFLOWERS 120ug   3.492689
# 14455                      5x 240ug Liquid Dosed Gummies   6.194249
# 14457              LSD - YODA - 50x BLOTTERS 140ug SWISS   3.153626
# 14458  100 x Alex Grey's Hofmann LSD Acid (100 x 100 ...   5.413293
# 14459           50x LSD Blotters 125ug Czech Silver Xtal   3.340626
# 14460                            5x 225ug Dalai Lama LSD  12.595622
# 14461            LSD - SHIVA - 500x BLOTTERS 140ug SWISS   2.477485
# 14462            25x LSD Blotters 185ug Mayan White Xtal   5.368349
# 14463        Beatles (Dutch Silver-Grey) 110ug - 50 hits   2.892367
# 14465                            1x 225ug Dalai Lama LSD  15.639742
# 14467                           50x 225ug Dalai Lama LSD  10.426208
# 14468            10x LSD Blotters 185ug Mayan White Xtal   5.681772
# 14472  10 x 225ug LSDJubilee Bunny Hofmanns Needlepoi...   6.743555
# 14476  10 x TragicallyHip's Dutch Shiva LSD Blotters ...   3.952174
# 14477                           10x 225ug Dalai Lama LSD  12.461311
# 14480                              25 Fat Freddy's 180ug   6.266890
# ...                                                  ...        ...
# 62973                               3x 160ug Hanuman LSD  10.341919
# 62975  NEW PRODUCT OFFER 50x HQ DUTCH LSD BLOTTERS 18...   4.801770
# 62977      50x Bears Blotter 200Âµg LSD-25 No FE Listing   5.879977
# 62978  **Promo**-10x150ug Premium Australian LSD blot...   8.741501
# 62981                              107.6ug 97%+ LSD (10)   0.972908
# 62982  100x Liquid LSD Drops 200Âµg LSD-25 No FE Listing   5.389852
# 62983  [ESCROW] 10 x 150ug Imported LSD Blotters - PU...  13.904552
# 62985  [ESCROW] 50 x 150ug Imported LSD Blotters - PU...  10.117242
# 62986          25x Liquid LSD Drops 200Âµg No FE Listing   5.310770
# 62987                    50 x â™¥LSD (200ug) IMPORTEDâ™¥  11.043138
# 62989                         10x Blotter | 140Âµg | LSD   6.023902
# 62991  [ESCROW] 30 x 150ug Imported LSD Blotters - PU...  12.438068
# 62992                         50x Blotter | 140Âµg | LSD   5.409218
# 62993  50x150ug Premium Australian LSD blotters.( Promo)   8.806829
# 62994  [ESCROW] 600 x 150ug Imported LSD Blotters - P...   7.564291
# 62995  1x WoW LSD 200ug - One hit of White on White Acid  14.004921
# 62998  [ESCROW] 250 x 150ug Imported LSD Blotters - P...   8.388373
# 62999                     1 x â™¥LSD (200ug) IMPORTEDâ™¥  21.138514
# 63000                             107.6ug 97%+ LSD (100)   6.080673
# 63001  [ESCROW] 200 x 150ug Imported LSD Blotters - P...   8.595118
# 63004                               5x 160ug Hanuman LSD   9.775765
# 63005   50x Liquid LSD Drops 200Âµg LSD-25 No FE Listing   5.879977
# 63009                     5 x â™¥LSD (200ug) IMPORTEDâ™¥  14.678069
# 63014  3x LSD Rolling Stones ~135Âµg ACID Blotter Psy...   7.647602
# 63015  5x LSD Rolling Stones ~135Âµg ACID Blotter Psy...   7.533715
# 63016  50x 420ug Dutch Rose Crystal Blotters <Heroic ...  24.364035
# 63018  10 x Highly potent and Clean LSD Smileys 115ug...   3.280038
# 63019  2 xLSD Anonymous ~150Âµg acid blotter psychede...   8.254437
# 63021                      50 hits White fluff LSD 200ug   7.840929
# 63022  2x LSD Rolling Stones ~135Âµg ACID Blotter Psy...   7.790687
#
#             Origin     Rating Dose  Quantity
# 14430      Germany      5.0/5  125         1
# 14431      Germany      5.0/5  125         1
# 14435      Germany      5.0/5  125         1
# 14436    Australia       ~5/5  120         1
# 14437    Australia       ~5/5  120         1
# 14439      Germany      4.8/5  225         1
# 14442      Germany      5.0/5  225         1
# 14444      Germany      5.0/5  225         1
# 14445      Germany      5.0/5  125         1
# 14446      Germany      4.8/5  225         1
# 14447       France  [0 deals]  130         1
# 14449      Germany      5.0/5  125         1
# 14450      Germany      4.8/5  225         1
# 14453    Australia       ~5/5  120         1
# 14454       France  [0 deals]  120         1
# 14455          USA      5.0/5  240         1
# 14457       France      5.0/5  140         1
# 14458      Germany      5.0/5  125         1
# 14459          USA      5.0/5  125         1
# 14460  Netherlands      5.0/5  225         1
# 14461       France      5.0/5  140         1
# 14462          USA      5.0/5  185         1
# 14463          USA      5.0/5  110         1
# 14465  Netherlands      5.0/5  225         1
# 14467  Netherlands      5.0/5  225         1
# 14468          USA      5.0/5  185         1
# 14472      Germany      5.0/5  225         1
# 14476       Canada      5.0/5  130         1
# 14477  Netherlands      5.0/5  225         1
# 14480  Netherlands      5.0/5  180         1
# ...            ...        ...  ...       ...
# 62973  Netherlands    4.968/5  160         1
# 62975  Netherlands     4.87/5  180         1
# 62977      Germany     4.95/5  200         1
# 62978    Australia     5.00/5  150         1
# 62981          USA     5.00/5    6         1
# 62982      Germany     4.95/5  200         1
# 62983    Australia    5.000/5  150         1
# 62985    Australia    5.000/5  150         1
# 62986      Germany     4.95/5  200         1
# 62987    Australia     4.95/5  200         1
# 62989  Netherlands     4.97/5  140         1
# 62991    Australia    5.000/5  150         1
# 62992  Netherlands     4.97/5  140         1
# 62993    Australia     5.00/5  150         1
# 62994    Australia    5.000/5  150         1
# 62995          USA     4.97/5  200         1
# 62998    Australia    5.000/5  150         1
# 62999    Australia     4.95/5  200         1
# 63000          USA     5.00/5    6         1
# 63001    Australia    5.000/5  150         1
# 63004  Netherlands    4.968/5  160         1
# 63005      Germany     4.95/5  200         1
# 63009    Australia     4.95/5  200         1
# 63014      Germany     4.87/5  135         1
# 63015      Germany     4.87/5  135         1
# 63016          USA    4.995/5  420         1
# 63018  Netherlands     4.67/5  115         1
# 63019      Germany     4.87/5  150         1
# 63021          USA  3~5 deals  200         1
# 63022      Germany     4.87/5  135         1
#
# [1168 rows x 6 columns]

# %%
# Normalizing the Price to Dosage
standardTabDose = 120

def normalizePrice(row):
    ratio = standardTabDose / float(row["Dose"])
    return round((float(row[" Price"]) * ratio), 2)

normalizedDf = acidDf
normalizedDf[" Price"] = normalizedDf.apply(lambda row: normalizePrice(row), axis=1)
normalizedDf["Dose"] = standardTabDose

#normalizedDf
normalizedDf.describe()
# Out:
#              Price    Dose  Quantity
# count  1168.000000  1168.0    1168.0
# mean      6.379443   120.0       1.0
# std       6.566750     0.0       0.0
# min       0.010000   120.0       1.0
# 25%       3.580000   120.0       1.0
# 50%       5.155000   120.0       1.0
# 75%       7.262500   120.0       1.0
# max     121.610000   120.0       1.0

# %%
acidDf = acidDf.drop([" Item", "Quantity"], axis=1)
acidDf[' Price'] = acidDf[' Price'].apply(lambda x: round(x,0))
acidDf = pd.get_dummies(acidDf, prefix="is")

# %%
# LETS GET TO PREDICTING
#DECISION TREE
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import f1_score

labels = acidDf[" Price"]
acidDf = acidDf.drop(" Price", axis=1)

# acidDf = acidDf
# labels = labels

X_train, X_test, y_train, y_test = train_test_split(acidDf, labels)

clf = tree.DecisionTreeRegressor()
# Call clf.fit(), and pass in X_train and y_train as parameters
clf.fit(X_train, y_train)

test_pred = clf.predict(X_test.values.reshape(1,-1)) # Use the .predict() method to have our model create predictions on the X_test variable

# Finally, pass in test_pred and y_test to the f1_score() object to get an f1_score!
#f1_score(test_pred, y_test, average="weighted")
clf.score(test_pred, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-554-2fc74e68e61a> in <module>()
#      17 clf.fit(X_train, y_train)
#      18
# ---> 19 test_pred = clf.predict(X_test.values.reshape(1,-1)) # Use the .predict() method to have our model create predictions on the X_test variable
#      20
#      21 # Finally, pass in test_pred and y_test to the f1_score() object to get an f1_score!
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     410         """
#     411         check_is_fitted(self, 'tree_')
# --> 412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     382                              "match the input. Model n_features is %s and "
#     383                              "input n_features is %s "
# --> 384                              % (self.n_features_, n_features))
#     385
#     386         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 98 and input n_features is 28616

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=25)
KNN.fit(X_train, y_train)
predictions = KNN.predict(X_test)
from sklearn.metrics import accuracy_score

acc = accuracy_score(predictions, y_test)
acc
